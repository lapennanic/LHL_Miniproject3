# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
import seaborn as sns

# %%
customers = pd.read_csv('../data/customers_cleaned.csv', delimiter=';')
customers
# Out:
#        income       age  years_with_bank  nbr_children  marital_status  \
# 0    0.154185  0.184312         0.408539      0.258591        0.132149
# 1   -0.726524  1.493070        -1.087435     -0.648298        0.132149
# 2   -0.188366 -0.234490         1.530520     -0.648298       -0.989614
# 3    1.123798  0.603115        -0.339448     -0.648298       -0.989614
# 4    0.983479  0.864867         1.904514      1.165479        2.375675
# ..        ...       ...              ...           ...             ...
# 742 -0.357478 -0.339191         0.782533      0.258591        2.375675
# 743  0.164864  0.707816         0.782533      0.258591        0.132149
# 744  1.738064  0.393714        -1.461429      1.165479        0.132149
# 745 -0.343735 -0.286841         1.156526     -0.648298        0.132149
# 746 -0.218692 -1.281497        -0.339448     -0.648298       -0.989614
#
#                                     city_name
# 0    Las Vegas
# 1    Los Angeles
# 2    Los Angeles
# ...

# %% [markdown]
# # Let's start by exploring Income

# %%
# Let's target income first, then years with bank

# most correlated features with income
corrmat = customers.corr()
top_corr_features = corrmat.index[abs(corrmat["income"])>0.20]
plt.figure(figsize=(10,10))
g = sns.heatmap(customers[top_corr_features].corr(),annot=True,cmap="RdYlGn_r")

# number of children is somewhat correlated to to income, nbr of children, age

# %%
sns.boxplot(x='nbr_children', y='income', data=customers)
# Out:
# <AxesSubplot:xlabel='nbr_children', ylabel='income'>

# %%
sns.boxplot(x='city_name', y='income', data=customers)
# Out:
# <AxesSubplot:xlabel='city_name', ylabel='income'>

# %%
sns.boxplot(x='marital_status', y='income', data=customers)
# Out:
# <AxesSubplot:xlabel='marital_status', ylabel='income'>

# %%
sns.scatterplot(x='age', y='income', data=customers)
# Out:
# <AxesSubplot:xlabel='age', ylabel='income'>

# %% [markdown]
# # Let's look at years w bank

# %%
# most correlated features with income
corrmat = customers.corr()
top_corr_features = corrmat.index[abs(corrmat["years_with_bank"])> .10]
plt.figure(figsize=(10,10))
g = sns.heatmap(customers[top_corr_features].corr(),annot=True,cmap="RdYlGn_r")
